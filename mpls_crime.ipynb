# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np

# %%
# %matplotlib inline

# %%
#create mplscrime dataframe
MPLS_Crime = os.path.join("mpls_crime_clean.csv")
crime_df=pd.read_csv(MPLS_Crime)

# %%
crime_df.head()
# Out:
#   Case_Number Case_NumberAlt NIBRS_Crime_Against  \
# 0   19-244586   MP2019244586           Property
# 1   19-122255   MP2019122255           Property
# 2   20-222716   MP2020222716           Property
# 3   20-703897   MP2020703897           Property
# 4   22-711824   MP2022711824           Property
#
#                 Offense_Category                        Offense  \
# 0  Burglary/Breaking & Entering   Burglary/Breaking & Entering
# 1        Larceny/Theft Offenses       Theft From Motor Vehicle
# 2  Burglary/Breaking & Entering   Burglary/Breaking & Entering
# 3        Larceny/Theft Offenses              All Other Larceny
# 4        Larceny/Theft Offenses              All Other Larceny
#
#                   Problem_Initial                   Problem_Final  \
# 0     Burglary Dwlng - Report (P)     Burglary Dwlng - Report (P)
# 1         Theft - Report Only (P)         Theft - Report Only (P)
# 2  Burglary Biz - In Progress (P)  Burglary Biz - In Progress (P)
# ...

# %%
slim_crime_df = crime_df.drop(["Case_NumberAlt", "Offense_Category", "wgsXAnon", "wgsYAnon", "Crime_Count", "Ward", "OBJECTID"], axis=1)
slim_crime_df.dtypes
# Out:
# Case_Number             object
# NIBRS_Crime_Against     object
# Offense                 object
# Problem_Initial         object
# Problem_Final           object
# Address                 object
# Precinct               float64
# Neighborhood            object
# Latitude               float64
# Longitude              float64
# Date_Occurred           object
# Time_Occurred           object
# Date_Reported           object
# Time_Reported           object
# dtype: object

# %%
# change ward and precinct to stings
# this bit I'm saving for later
# slim_crime_df.replace('4.0', "Fourth")
slim_crime_df['Precinct'] = slim_crime_df['Precinct'].astype(str)
slim_crime_df.dtypes
# Out:
# Case_Number             object
# NIBRS_Crime_Against     object
# Offense                 object
# Problem_Initial         object
# Problem_Final           object
# Address                 object
# Precinct                object
# Neighborhood            object
# Latitude               float64
# Longitude              float64
# Date_Occurred           object
# Time_Occurred           object
# Date_Reported           object
# Time_Reported           object
# dtype: object

# %%
# slim_crime_df['Ward'] = slim_crime_df['Ward'].astype(str)
# slim_crime_df.dtypes

# %%
#replace float with string values
slim_crime_df.replace('4.0', "Fourth")
slim_crime_df
# Out:
#        Case_Number NIBRS_Crime_Against                        Offense  \
# 0        19-244586           Property   Burglary/Breaking & Entering
# 1        19-122255           Property       Theft From Motor Vehicle
# 2        20-222716           Property   Burglary/Breaking & Entering
# 3        20-703897           Property              All Other Larceny
# 4        22-711824           Property              All Other Larceny
# ...            ...                 ...                            ...
# 161121   21-710504           Property              All Other Larceny
# 161122   21-285759           Property              All Other Larceny
# 161123   22-700897           Property       Theft From Motor Vehicle
# 161124   21-185969           Property                        Robbery
# 161125   19-268803           Property              All Other Larceny
#
#                        Problem_Initial                   Problem_Final  \
# ...

# %%
# This was not strictly necessary and it's bugging me
precinct=slim_crime_df.replace('4.0', "Fourth").replace("1.0", "First").replace("2.0", "Second").replace("3.0", "Third").replace("5.0", "Fifth")
precinct
# Out:
#        Case_Number NIBRS_Crime_Against                        Offense  \
# 0        19-244586           Property   Burglary/Breaking & Entering
# 1        19-122255           Property       Theft From Motor Vehicle
# 2        20-222716           Property   Burglary/Breaking & Entering
# 3        20-703897           Property              All Other Larceny
# 4        22-711824           Property              All Other Larceny
# ...            ...                 ...                            ...
# 161121   21-710504           Property              All Other Larceny
# 161122   21-285759           Property              All Other Larceny
# 161123   22-700897           Property       Theft From Motor Vehicle
# 161124   21-185969           Property                        Robbery
# 161125   19-268803           Property              All Other Larceny
#
#                        Problem_Initial                   Problem_Final  \
# ...

# %%
precinct.replace('4.0', "Fourth")
# Out:
#        Case_Number NIBRS_Crime_Against                        Offense  \
# 0        19-244586           Property   Burglary/Breaking & Entering
# 1        19-122255           Property       Theft From Motor Vehicle
# 2        20-222716           Property   Burglary/Breaking & Entering
# 3        20-703897           Property              All Other Larceny
# 4        22-711824           Property              All Other Larceny
# ...            ...                 ...                            ...
# 161121   21-710504           Property              All Other Larceny
# 161122   21-285759           Property              All Other Larceny
# 161123   22-700897           Property       Theft From Motor Vehicle
# 161124   21-185969           Property                        Robbery
# 161125   19-268803           Property              All Other Larceny
#
#                        Problem_Initial                   Problem_Final  \
# ...

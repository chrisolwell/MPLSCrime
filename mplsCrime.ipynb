# %%
import pandas as pd
import os
import datetime
import matplotlib.pyplot as plt
import numpy as np
from matplotlib import style
from matplotlib.patches import ConnectionPatch
import mplcyberpunk

# %%
# %matplotlib inline

# %%
#create mplscrime dataframe
MPLS_Crime = os.path.join("Crime_Data.csv")
crime_df=pd.read_csv(MPLS_Crime)

# %%
crime_df.head()
# Out:
#            X          Y                    Type Case_Number Case_NumberAlt  \
# 0 -93.316750  45.038778  Crime Offenses (NIBRS)   19-244586   MP2019244586
# 1 -93.293968  45.039344  Crime Offenses (NIBRS)   19-122255   MP2019122255
# 2 -93.249955  44.949220       Shots Fired Calls   21-117936            NaN
# 3 -93.275347  44.977582  Crime Offenses (NIBRS)   20-222716   MP2020222716
# 4 -93.226094  44.935953  Crime Offenses (NIBRS)   20-703897   MP2020703897
#
#             Reported_Date           Occurred_Date NIBRS_Crime_Against  \
# 0  2019/08/15 21:39:00+00  2019/08/15 16:00:00+00           Property
# 1  2019/05/01 13:10:00+00  2019/05/01 10:15:00+00           Property
# 2  2021/06/01 07:53:55+00  2021/06/01 07:53:55+00      Non NIBRS Data
# 3  2020/08/27 03:26:00+00  2020/08/26 22:54:00+00           Property
# 4  2020/07/12 11:24:00+00  2020/07/12 09:30:00+00           Property
#
#       NIBRS_Group      NIBRS_Code  ...               Address Precinct  \
# 0         Group A             220  ...  0045XX VINCENT AVE N      4.0
# 1         Group A            23F   ...   0046XX DUPONT AVE N      4.0
# 2  Non NIBRS Data  Non NIBRS Data  ...     0029XX 17TH AVE S      3.0
# 3         Group A             220  ...   0007XX HENNEPIN AVE      1.0
# 4         Group A            23H   ...      0032XX 37TH ST E      3.0
#
#      Neighborhood  Ward  Latitude  Longitude      wgsXAnon      wgsYAnon  \
# 0         Victory   4.0  45.03877  -93.31675 -1.038797e+07  5.627628e+06
# 1  Lind - Bohanon   4.0  45.03934  -93.29396 -1.038544e+07  5.627718e+06
# 2   East Phillips   9.0  44.94921  -93.24995 -1.038054e+07  5.613531e+06
# 3   Downtown West   7.0  44.97758  -93.27534 -1.038336e+07  5.617993e+06
# 4        Standish  12.0  44.93595  -93.22609 -1.037788e+07  5.611444e+06
#
#    Crime_Count  OBJECTID
# 0            1         1
# 1            1         2
# 2            1         3
# 3            1         4
# 4            1         5
#
# [5 rows x 24 columns]

# %%
crime_df.dtypes
# Out:
# X                      float64
# Y                      float64
# Type                    object
# Case_Number             object
# Case_NumberAlt          object
# Reported_Date           object
# Occurred_Date           object
# NIBRS_Crime_Against     object
# NIBRS_Group             object
# NIBRS_Code              object
# Offense_Category        object
# Offense                 object
# Problem_Initial         object
# Problem_Final           object
# Address                 object
# Precinct               float64
# Neighborhood            object
# Ward                   float64
# Latitude               float64
# Longitude              float64
# wgsXAnon               float64
# wgsYAnon               float64
# Crime_Count              int64
# OBJECTID                 int64
# dtype: object

# %%
now = datetime.datetime.now()
print("The time right now is ", now)
# Out:
# The time right now is  2022-12-02 00:19:27.558848

# %%
crime_df.count()
# Out:
# X                      200930
# Y                      200930
# Type                   200930
# Case_Number            200930
# Case_NumberAlt         171522
# Reported_Date          200930
# Occurred_Date          200929
# NIBRS_Crime_Against    200930
# NIBRS_Group            200930
# NIBRS_Code             200930
# Offense_Category       200930
# Offense                200930
# Problem_Initial        165304
# Problem_Final          165304
# Address                200930
# Precinct               199683
# Neighborhood           199619
# Ward                   199513
# Latitude               200930
# Longitude              200930
# wgsXAnon               200930
# wgsYAnon               200930
# Crime_Count            200930
# OBJECTID               200930
# dtype: int64

# %%
#Look for missing values
crime_df.isnull()
# Out:
#             X      Y   Type  Case_Number  Case_NumberAlt  Reported_Date  \
# 0       False  False  False        False           False          False
# 1       False  False  False        False           False          False
# 2       False  False  False        False            True          False
# 3       False  False  False        False           False          False
# 4       False  False  False        False           False          False
# ...       ...    ...    ...          ...             ...            ...
# 200925  False  False  False        False           False          False
# 200926  False  False  False        False            True          False
# 200927  False  False  False        False           False          False
# 200928  False  False  False        False           False          False
# 200929  False  False  False        False            True          False
#
#         Occurred_Date  NIBRS_Crime_Against  NIBRS_Group  NIBRS_Code  ...  \
# 0               False                False        False       False  ...
# 1               False                False        False       False  ...
# 2               False                False        False       False  ...
# 3               False                False        False       False  ...
# 4               False                False        False       False  ...
# ...               ...                  ...          ...         ...  ...
# 200925          False                False        False       False  ...
# 200926          False                False        False       False  ...
# 200927          False                False        False       False  ...
# 200928          False                False        False       False  ...
# 200929          False                False        False       False  ...
#
#         Address  Precinct  Neighborhood   Ward  Latitude  Longitude  wgsXAnon  \
# 0         False     False         False  False     False      False     False
# 1         False     False         False  False     False      False     False
# 2         False     False         False  False     False      False     False
# 3         False     False         False  False     False      False     False
# 4         False     False         False  False     False      False     False
# ...         ...       ...           ...    ...       ...        ...       ...
# 200925    False     False         False  False     False      False     False
# 200926    False     False         False  False     False      False     False
# 200927    False     False         False  False     False      False     False
# 200928    False     False         False  False     False      False     False
# 200929    False     False         False  False     False      False     False
#
#         wgsYAnon  Crime_Count  OBJECTID
# 0          False        False     False
# 1          False        False     False
# 2          False        False     False
# 3          False        False     False
# 4          False        False     False
# ...          ...          ...       ...
# 200925     False        False     False
# 200926     False        False     False
# 200927     False        False     False
# 200928     False        False     False
# 200929     False        False     False
#
# [200930 rows x 24 columns]

# %%
#get total of empty rows
crime_df.isnull().sum()
# Out:
# X                          0
# Y                          0
# Type                       0
# Case_Number                0
# Case_NumberAlt         29408
# Reported_Date              0
# Occurred_Date              1
# NIBRS_Crime_Against        0
# NIBRS_Group                0
# NIBRS_Code                 0
# Offense_Category           0
# Offense                    0
# Problem_Initial        35626
# Problem_Final          35626
# Address                    0
# Precinct                1247
# Neighborhood            1311
# Ward                    1417
# Latitude                   0
# Longitude                  0
# wgsXAnon                   0
# wgsYAnon                   0
# Crime_Count                0
# OBJECTID                   0
# dtype: int64

# %%
#determine if there are not any missing values
crime_df.notnull().sum()
# Out:
# X                      200930
# Y                      200930
# Type                   200930
# Case_Number            200930
# Case_NumberAlt         171522
# Reported_Date          200930
# Occurred_Date          200929
# NIBRS_Crime_Against    200930
# NIBRS_Group            200930
# NIBRS_Code             200930
# Offense_Category       200930
# Offense                200930
# Problem_Initial        165304
# Problem_Final          165304
# Address                200930
# Precinct               199683
# Neighborhood           199619
# Ward                   199513
# Latitude               200930
# Longitude              200930
# wgsXAnon               200930
# wgsYAnon               200930
# Crime_Count            200930
# OBJECTID               200930
# dtype: int64

# %%
#testing dtype on single column
crime_df["Occurred_Date"].dtype
# Out:
# dtype('O')

# %%
list(crime_df.columns)
# Out:
# ['X',
#  'Y',
#  'Type',
#  'Case_Number',
#  'Case_NumberAlt',
#  'Reported_Date',
#  'Occurred_Date',
#  'NIBRS_Crime_Against',
#  'NIBRS_Group',
#  'NIBRS_Code',
#  'Offense_Category',
#  'Offense',
#  'Problem_Initial',
#  'Problem_Final',
#  'Address',
#  'Precinct',
#  'Neighborhood',
#  'Ward',
#  'Latitude',
#  'Longitude',
#  'wgsXAnon',
#  'wgsYAnon',
#  'Crime_Count',
#  'OBJECTID']

# %%
#Create a list of occurred date in seperate file
occurred_date = crime_df['Occurred_Date'].tolist()
occurred_date
# Out:
# ['2019/08/15 16:00:00+00',
#  '2019/05/01 10:15:00+00',
#  '2021/06/01 07:53:55+00',
#  '2020/08/26 22:54:00+00',
#  '2020/07/12 09:30:00+00',
#  '2022/10/04 08:00:00+00',
#  '2022/05/07 03:29:00+00',
#  '2022/06/02 22:05:12+00',
#  '2022/07/16 17:08:00+00',
#  '2022/01/16 08:33:11+00',
#  '2021/04/14 02:28:39+00',
#  '2021/10/08 02:00:00+00',
#  '2021/12/14 20:31:36+00',
#  '2022/08/06 20:10:00+00',
#  '2019/10/20 03:29:29+00',
#  '2021/03/21 02:18:36+00',
#  '2022/05/21 01:27:45+00',
#  '2019/11/21 13:18:00+00',
#  '2020/03/15 23:00:00+00',
#  '2021/01/17 21:50:00+00',
#  '2020/04/08 20:20:00+00',
#  '2020/01/08 17:00:00+00',
#  '2022/04/14 12:00:00+00',
#  '2019/01/02 18:45:00+00',
#  '2019/07/18 11:56:00+00',
#  '2022/09/13 00:07:58+00',
#  '2022/02/09 18:00:00+00',
#  '2022/09/12 00:00:00+00',
#  '2022/06/18 21:00:00+00',
#  '2022/08/05 05:51:00+00',
#  '2021/01/01 04:00:15+00',
#  '2021/01/07 20:35:00+00',
#  '2021/12/22 03:15:36+00',
#  '2020/08/26 20:00:00+00',
#  '2021/03/07 02:45:00+00',
#  '2021/12/03 02:54:21+00',
#  '2022/10/08 21:00:00+00',
#  '2019/11/24 01:08:00+00',
#  '2022/07/06 02:10:00+00',
#  '2019/11/09 23:10:00+00',
#  '2020/04/30 21:17:00+00',
#  '2022/10/02 20:38:00+00',
#  '2021/05/14 00:00:00+00',
#  '2019/08/01 23:30:00+00',
#  '2021/08/29 00:55:06+00',
#  '2021/02/22 22:02:20+00',
#  '2022/10/28 00:47:00+00',
#  '2019/10/13 21:00:00+00',
#  '2020/09/17 00:00:00+00',
#  '2021/09/18 22:00:00+00',
#  '2019/05/29 11:09:00+00',
#  '2021/04/21 01:00:00+00',
#  '2020/05/15 04:00:00+00',
#  '2021/12/10 03:00:00+00',
#  '2021/10/20 20:00:00+00',
#  '2020/10/05 13:36:00+00',
#  '2021/01/18 19:30:00+00',
#  '2019/08/25 14:22:00+00',
#  '2019/08/30 16:00:00+00',
#  '2019/10/18 22:35:00+00',
#  '2021/11/16 18:38:31+00',
#  '2021/02/14 20:15:17+00',
#  '2021/09/19 01:49:32+00',
#  '2021/03/05 10:33:00+00',
#  '2019/12/09 21:00:00+00',
#  '2020/11/17 21:00:00+00',
#  '2021/08/19 12:00:00+00',
#  '2020/02/01 00:00:00+00',
#  '2021/01/19 17:00:00+00',
#  '2020/03/10 20:15:00+00',
#  '2022/08/17 01:00:00+00',
#  '2021/05/07 19:00:00+00',
#  '2019/12/13 01:56:00+00',
#  '2019/06/29 16:00:00+00',
#  '2022/06/08 16:13:00+00',
#  '2019/11/13 22:00:00+00',
#  '2021/07/04 01:00:00+00',
#  '2021/09/14 14:00:00+00',
#  '2019/03/23 09:16:00+00',
#  '2021/08/01 19:00:00+00',
#  '2020/08/18 00:26:38+00',
#  '2019/05/21 18:30:00+00',
#  '2022/09/02 10:30:00+00',
#  '2021/04/21 00:00:00+00',
#  '2022/01/03 12:00:00+00',
#  '2022/04/14 12:45:00+00',
#  '2022/08/04 14:20:00+00',
#  '2020/04/18 21:30:00+00',
#  '2020/09/18 21:47:47+00',
#  '2020/03/16 11:08:00+00',
#  '2022/10/23 19:40:40+00',
#  '2021/08/13 19:00:00+00',
#  '2021/05/01 22:00:00+00',
#  '2020/02/20 18:30:00+00',
#  '2022/04/06 01:00:00+00',
#  '2019/08/30 06:30:00+00',
#  '2020/05/23 21:32:51+00',
#  '2022/09/08 00:35:00+00',
#  '2021/09/11 00:00:00+00',
#  '2020/08/03 00:01:00+00',
#  '2020/10/05 14:39:00+00',
#  '2022/06/09 14:22:00+00',
#  '2022/05/15 14:00:00+00',
#  '2022/07/23 21:40:00+00',
#  '2022/08/02 20:52:43+00',
#  '2021/01/01 01:37:03+00',
#  '2021/03/31 08:15:00+00',
#  '2021/09/19 13:00:00+00',
#  '2021/09/10 11:30:00+00',
#  '2020/08/16 02:44:10+00',
#  '2022/07/05 02:30:00+00',
#  '2022/10/11 02:31:27+00',
#  '2022/10/06 23:50:00+00',
#  '2019/10/24 00:00:00+00',
#  '2020/05/27 13:04:00+00',
#  '2021/01/30 00:00:00+00',
#  '2019/09/25 23:00:00+00',
#  '2021/11/01 12:09:00+00',
#  '2020/10/03 03:18:00+00',
#  '2020/12/09 20:38:13+00',
#  '2020/08/15 17:30:00+00',
#  '2020/04/06 00:00:00+00',
#  '2021/01/30 01:00:00+00',
#  '2019/11/13 09:00:00+00',
#  ...]

# %%
# #Split date and time of day into seperate columns
# for date in occurred_date:
#     print(date.split(), len(date.split()))

# %%
#I wonder what I did here?
date = []

# %%
#Split date columns into date and time columns
crime_df['Date_Occurred']=pd.to_datetime(crime_df['Occurred_Date']).dt.date
crime_df['Time_Occurred']=pd.to_datetime(crime_df['Occurred_Date']).dt.time

crime_df['Date_Reported']=pd.to_datetime(crime_df['Reported_Date']).dt.date
crime_df['Time_Reported']=pd.to_datetime(crime_df['Reported_Date']).dt.time

# %%
crime_df
# Out:
#                 X          Y                    Type Case_Number  \
# 0      -93.316750  45.038778  Crime Offenses (NIBRS)   19-244586
# 1      -93.293968  45.039344  Crime Offenses (NIBRS)   19-122255
# 2      -93.249955  44.949220       Shots Fired Calls   21-117936
# 3      -93.275347  44.977582  Crime Offenses (NIBRS)   20-222716
# 4      -93.226094  44.935953  Crime Offenses (NIBRS)   20-703897
# ...           ...        ...                     ...         ...
# 200925 -93.220366  44.902660  Crime Offenses (NIBRS)   22-700897
# 200926 -93.292435  45.014930       Shots Fired Calls   21-082066
# 200927 -93.265202  44.950148  Crime Offenses (NIBRS)   21-185969
# 200928 -93.276637  44.942251  Crime Offenses (NIBRS)   19-268803
# 200929 -93.293352  44.991977       Shots Fired Calls   22-163279
#
#        Case_NumberAlt           Reported_Date           Occurred_Date  \
# 0        MP2019244586  2019/08/15 21:39:00+00  2019/08/15 16:00:00+00
# 1        MP2019122255  2019/05/01 13:10:00+00  2019/05/01 10:15:00+00
# 2                 NaN  2021/06/01 07:53:55+00  2021/06/01 07:53:55+00
# 3        MP2020222716  2020/08/27 03:26:00+00  2020/08/26 22:54:00+00
# 4        MP2020703897  2020/07/12 11:24:00+00  2020/07/12 09:30:00+00
# ...               ...                     ...                     ...
# 200925   MP2022700897  2022/01/28 18:35:00+00  2022/01/22 18:30:00+00
# 200926            NaN  2021/04/19 19:37:55+00  2021/04/19 19:37:55+00
# 200927   MP2021185969  2021/08/18 02:58:00+00  2021/08/18 00:00:00+00
# 200928   MP2019268803  2019/09/05 23:32:00+00  2019/08/12 12:30:00+00
# 200929            NaN  2022/07/18 09:54:36+00  2022/07/18 09:54:36+00
#
#        NIBRS_Crime_Against     NIBRS_Group      NIBRS_Code  ...  Latitude  \
# 0                Property          Group A             220  ...  45.03877
# 1                Property          Group A            23F   ...  45.03934
# 2           Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...  44.94921
# 3                Property          Group A             220  ...  44.97758
# 4                Property          Group A            23H   ...  44.93595
# ...                    ...             ...             ...  ...       ...
# 200925           Property          Group A            23F   ...  44.90266
# 200926      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...  45.01493
# 200927           Property          Group A             120  ...  44.95014
# 200928           Property          Group A            23H   ...  44.94225
# 200929      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data  ...  44.99197
#
#        Longitude      wgsXAnon      wgsYAnon Crime_Count  OBJECTID  \
# 0      -93.31675 -1.038797e+07  5.627628e+06           1         1
# 1      -93.29396 -1.038544e+07  5.627718e+06           1         2
# 2      -93.24995 -1.038054e+07  5.613531e+06           1         3
# 3      -93.27534 -1.038336e+07  5.617993e+06           1         4
# 4      -93.22609 -1.037788e+07  5.611444e+06           1         5
# ...          ...           ...           ...         ...       ...
# 200925 -93.22036 -1.037724e+07  5.606210e+06           1    200926
# 200926 -93.29243 -1.038527e+07  5.623872e+06           1    200927
# 200927 -93.26520 -1.038223e+07  5.613677e+06           1    200928
# 200928 -93.27663 -1.038351e+07  5.612435e+06           1    200929
# 200929 -93.29335 -1.038537e+07  5.620259e+06           1    200930
#
#        Date_Occurred  Time_Occurred  Date_Reported  Time_Reported
# 0         2019-08-15       16:00:00     2019-08-15       21:39:00
# 1         2019-05-01       10:15:00     2019-05-01       13:10:00
# 2         2021-06-01       07:53:55     2021-06-01       07:53:55
# 3         2020-08-26       22:54:00     2020-08-27       03:26:00
# 4         2020-07-12       09:30:00     2020-07-12       11:24:00
# ...              ...            ...            ...            ...
# 200925    2022-01-22       18:30:00     2022-01-28       18:35:00
# 200926    2021-04-19       19:37:55     2021-04-19       19:37:55
# 200927    2021-08-18       00:00:00     2021-08-18       02:58:00
# 200928    2019-08-12       12:30:00     2019-09-05       23:32:00
# 200929    2022-07-18       09:54:36     2022-07-18       09:54:36
#
# [200930 rows x 28 columns]

# %%
#No longer want to drop these coloumns
# mpls_crime_df= crime_df.drop(["X", "Y", 'Occurred_Date', "Reported_Date"], axis=1)
mpls_crime_df= crime_df.drop(["X", "Y"], axis=1)
mpls_crime_df
# Out:
#                           Type Case_Number Case_NumberAlt  \
# 0       Crime Offenses (NIBRS)   19-244586   MP2019244586
# 1       Crime Offenses (NIBRS)   19-122255   MP2019122255
# 2            Shots Fired Calls   21-117936            NaN
# 3       Crime Offenses (NIBRS)   20-222716   MP2020222716
# 4       Crime Offenses (NIBRS)   20-703897   MP2020703897
# ...                        ...         ...            ...
# 200925  Crime Offenses (NIBRS)   22-700897   MP2022700897
# 200926       Shots Fired Calls   21-082066            NaN
# 200927  Crime Offenses (NIBRS)   21-185969   MP2021185969
# 200928  Crime Offenses (NIBRS)   19-268803   MP2019268803
# 200929       Shots Fired Calls   22-163279            NaN
#
#                  Reported_Date           Occurred_Date NIBRS_Crime_Against  \
# 0       2019/08/15 21:39:00+00  2019/08/15 16:00:00+00           Property
# 1       2019/05/01 13:10:00+00  2019/05/01 10:15:00+00           Property
# 2       2021/06/01 07:53:55+00  2021/06/01 07:53:55+00      Non NIBRS Data
# 3       2020/08/27 03:26:00+00  2020/08/26 22:54:00+00           Property
# 4       2020/07/12 11:24:00+00  2020/07/12 09:30:00+00           Property
# ...                        ...                     ...                 ...
# 200925  2022/01/28 18:35:00+00  2022/01/22 18:30:00+00           Property
# 200926  2021/04/19 19:37:55+00  2021/04/19 19:37:55+00      Non NIBRS Data
# 200927  2021/08/18 02:58:00+00  2021/08/18 00:00:00+00           Property
# 200928  2019/09/05 23:32:00+00  2019/08/12 12:30:00+00           Property
# 200929  2022/07/18 09:54:36+00  2022/07/18 09:54:36+00      Non NIBRS Data
#
#            NIBRS_Group      NIBRS_Code               Offense_Category  \
# 0              Group A             220  Burglary/Breaking & Entering
# 1              Group A            23F         Larceny/Theft Offenses
# 2       Non NIBRS Data  Non NIBRS Data              Shots Fired Calls
# 3              Group A             220  Burglary/Breaking & Entering
# 4              Group A            23H         Larceny/Theft Offenses
# ...                ...             ...                            ...
# 200925         Group A            23F         Larceny/Theft Offenses
# 200926  Non NIBRS Data  Non NIBRS Data              Shots Fired Calls
# 200927         Group A             120                       Robbery
# 200928         Group A            23H         Larceny/Theft Offenses
# 200929  Non NIBRS Data  Non NIBRS Data              Shots Fired Calls
#
#                               Offense  ...  Latitude Longitude      wgsXAnon  \
# 0       Burglary/Breaking & Entering   ...  45.03877 -93.31675 -1.038797e+07
# 1           Theft From Motor Vehicle   ...  45.03934 -93.29396 -1.038544e+07
# 2            Sound of Shots Fired (P)  ...  44.94921 -93.24995 -1.038054e+07
# 3       Burglary/Breaking & Entering   ...  44.97758 -93.27534 -1.038336e+07
# 4                  All Other Larceny   ...  44.93595 -93.22609 -1.037788e+07
# ...                               ...  ...       ...       ...           ...
# 200925      Theft From Motor Vehicle   ...  44.90266 -93.22036 -1.037724e+07
# 200926     ShotSpotter Activation (P)  ...  45.01493 -93.29243 -1.038527e+07
# 200927                       Robbery   ...  44.95014 -93.26520 -1.038223e+07
# 200928             All Other Larceny   ...  44.94225 -93.27663 -1.038351e+07
# 200929     ShotSpotter Activation (P)  ...  44.99197 -93.29335 -1.038537e+07
#
#             wgsYAnon Crime_Count  OBJECTID  Date_Occurred  Time_Occurred  \
# 0       5.627628e+06           1         1     2019-08-15       16:00:00
# 1       5.627718e+06           1         2     2019-05-01       10:15:00
# 2       5.613531e+06           1         3     2021-06-01       07:53:55
# 3       5.617993e+06           1         4     2020-08-26       22:54:00
# 4       5.611444e+06           1         5     2020-07-12       09:30:00
# ...              ...         ...       ...            ...            ...
# 200925  5.606210e+06           1    200926     2022-01-22       18:30:00
# 200926  5.623872e+06           1    200927     2021-04-19       19:37:55
# 200927  5.613677e+06           1    200928     2021-08-18       00:00:00
# 200928  5.612435e+06           1    200929     2019-08-12       12:30:00
# 200929  5.620259e+06           1    200930     2022-07-18       09:54:36
#
#         Date_Reported  Time_Reported
# 0          2019-08-15       21:39:00
# 1          2019-05-01       13:10:00
# 2          2021-06-01       07:53:55
# 3          2020-08-27       03:26:00
# 4          2020-07-12       11:24:00
# ...               ...            ...
# 200925     2022-01-28       18:35:00
# 200926     2021-04-19       19:37:55
# 200927     2021-08-18       02:58:00
# 200928     2019-09-05       23:32:00
# 200929     2022-07-18       09:54:36
#
# [200930 rows x 26 columns]

# %%
#Getting unique values to determine necessity of columns

#What is this column? Looks largely useless?
mpls_crime_df.NIBRS_Group.unique()
# Out:
# array(['Group A', 'Non NIBRS Data'], dtype=object)

# %%
mpls_crime_df.Offense_Category.unique()
# Out:
# array(['Burglary/Breaking & Entering ', 'Larceny/Theft Offenses ',
#        'Shots Fired Calls', 'Robbery ',
#        'Subset of NIBRS Assault Offenses', 'Motor Vehicle Theft ',
#        'Weapon Law Violations ',
#        'Destruction/Damage/Vandalism of Property ', 'Assault Offenses ',
#        'Fraud Offenses ', 'Stolen Property Offenses ', 'Sex Offenses ',
#        'Drug/Narcotic Offenses ', 'Counterfeiting/Forgery ',
#        'Embezzlement ', 'Kidnapping/Abduction ', 'Arson ',
#        'Subset of NIBRS Robbery', 'Gunshot Wound Victims',
#        'Pornography/Obscene Material ', 'Homicide Offenses ',
#        'Animal Cruelty ', 'Extortion/Blackmail ', 'Human Trafficking ',
#        'Gambling Offenses ', 'Prostitution Offenses ', 'Bribery '],
#       dtype=object)

# %%
mpls_crime_df.Offense.unique()
# Out:
# array(['Burglary/Breaking & Entering ', 'Theft From Motor Vehicle ',
#        'Sound of Shots Fired (P)', 'All Other Larceny ', 'Robbery ',
#        'Shoplifting ', 'ShotSpotter Activation (P)',
#        'Domestic Aggravated Assault - Subset of Assault',
#        'Motor Vehicle Theft ', 'Weapon Law Violations ',
#        'Destruction/Damage/Vandalism of Property ', 'Simple Assault ',
#        'Theft of Motor Vehicle Parts or Accessories ',
#        'Credit Card/Automated Teller Machine Fraud ', 'Purse-snatching ',
#        'Aggravated Assault ', 'Identity Theft ',
#        'Stolen Property Offenses ', 'Sex Offenses',
#        'Drug/Narcotic Violations ', 'Counterfeiting/Forgery ',
#        'Drug Equipment Violations ', 'Embezzlement ',
#        'Kidnapping/Abduction ', 'Arson ', 'Theft From Building ',
#        'Carjacking - Subset of Robbery', 'Shooting (PFE)',
#        'False Pretenses/Swindle/Confidence Game ', 'Intimidation ',
#        'Wire Fraud ', 'Shooting Report Only (P)', 'Gunshot Wound Victims',
#        'Pornography/Obscene Material ', 'Negligent Manslaughter ',
#        'Murder and Nonnegligent Manslaughter ', 'Animal Cruelty ',
#        'Hacking/Computer Invasion ', 'Extortion/Blackmail ',
#        'Impersonation ', 'Pocket-picking ',
#        'Human Trafficking, Involuntary Servitude ',
#        'Justifiable Homicide ', 'Betting/Wagering ',
#        'Human Trafficking, Commercial Sex Acts ', 'Prostitution ',
#        'Gambling Equipment Violations ', 'Purchasing Prostitution ',
#        'Welfare Fraud ', 'Operating/Promoting/Assisting Gambling ',
#        'Theft From Coin-Operated Machine or Device ',
#        'Assisting or Promoting Prostitution ', 'Bribery '], dtype=object)

# %%
# Useful but verify non NIBRS Data is shotspotter data or whatever
mpls_crime_df.NIBRS_Crime_Against.unique()
# Out:
# array(['Property ', 'Non NIBRS Data', 'Society ', 'Person ',
#        'Not a Crime '], dtype=object)

# %%
# I Dont know what these codes mean so I'm keeping that column for now
mpls_crime_df.NIBRS_Code.unique()
# Out:
# array(['220', '23F ', 'Non NIBRS Data', '23H ', '120', '23C ', '240',
#        '520', '290', '13B ', '23G ', '26B ', '23B ', '13A ', '26F ',
#        '280', '11A ', '35A ', '250', '35B ', '270', '100', '200', '23D ',
#        '26A ', '13C ', '11D ', '26E ', '11B ', '370', '11C ', '09B ',
#        '09A ', '720', '26G ', '210', '26C ', '23A ', '64B ', '09C ',
#        '39A ', '64A ', '40A ', '39C ', '40C ', '26D ', '39B ', '23E ',
#        '40B ', '510', '36B ', '36A '], dtype=object)

# %%
# interesting column
mpls_crime_df.Type.unique()
# Out:
# array(['Crime Offenses (NIBRS)', 'Shots Fired Calls',
#        'Additional Crime Metrics', 'Gunshot Wound Victims'], dtype=object)

# %%
mpls_crime_df.head()
# Out:
#                      Type Case_Number Case_NumberAlt           Reported_Date  \
# 0  Crime Offenses (NIBRS)   19-244586   MP2019244586  2019/08/15 21:39:00+00
# 1  Crime Offenses (NIBRS)   19-122255   MP2019122255  2019/05/01 13:10:00+00
# 2       Shots Fired Calls   21-117936            NaN  2021/06/01 07:53:55+00
# 3  Crime Offenses (NIBRS)   20-222716   MP2020222716  2020/08/27 03:26:00+00
# 4  Crime Offenses (NIBRS)   20-703897   MP2020703897  2020/07/12 11:24:00+00
#
#             Occurred_Date NIBRS_Crime_Against     NIBRS_Group      NIBRS_Code  \
# 0  2019/08/15 16:00:00+00           Property          Group A             220
# 1  2019/05/01 10:15:00+00           Property          Group A            23F
# 2  2021/06/01 07:53:55+00      Non NIBRS Data  Non NIBRS Data  Non NIBRS Data
# 3  2020/08/26 22:54:00+00           Property          Group A             220
# 4  2020/07/12 09:30:00+00           Property          Group A            23H
#
#                 Offense_Category                        Offense  ...  \
# 0  Burglary/Breaking & Entering   Burglary/Breaking & Entering   ...
# 1        Larceny/Theft Offenses       Theft From Motor Vehicle   ...
# 2              Shots Fired Calls       Sound of Shots Fired (P)  ...
# 3  Burglary/Breaking & Entering   Burglary/Breaking & Entering   ...
# 4        Larceny/Theft Offenses              All Other Larceny   ...
#
#    Latitude Longitude      wgsXAnon      wgsYAnon Crime_Count  OBJECTID  \
# 0  45.03877 -93.31675 -1.038797e+07  5.627628e+06           1         1
# 1  45.03934 -93.29396 -1.038544e+07  5.627718e+06           1         2
# 2  44.94921 -93.24995 -1.038054e+07  5.613531e+06           1         3
# 3  44.97758 -93.27534 -1.038336e+07  5.617993e+06           1         4
# 4  44.93595 -93.22609 -1.037788e+07  5.611444e+06           1         5
#
#    Date_Occurred  Time_Occurred  Date_Reported  Time_Reported
# 0     2019-08-15       16:00:00     2019-08-15       21:39:00
# 1     2019-05-01       10:15:00     2019-05-01       13:10:00
# 2     2021-06-01       07:53:55     2021-06-01       07:53:55
# 3     2020-08-26       22:54:00     2020-08-27       03:26:00
# 4     2020-07-12       09:30:00     2020-07-12       11:24:00
#
# [5 rows x 26 columns]

# %%
#Isolate (and hopefully eventualy separate) spotshotter calls
spotshotter_calls_df = mpls_crime_df.loc[mpls_crime_df['NIBRS_Group']== "Non NIBRS Data"]
spotshotter_calls_df
# Out:
#                      Type Case_Number Case_NumberAlt           Reported_Date  \
# 2       Shots Fired Calls   21-117936            NaN  2021/06/01 07:53:55+00
# 7       Shots Fired Calls   22-120402            NaN  2022/06/02 22:05:12+00
# 9       Shots Fired Calls   22-010627            NaN  2022/01/16 08:33:11+00
# 10      Shots Fired Calls   21-077752            NaN  2021/04/14 02:28:39+00
# 12      Shots Fired Calls   21-286262            NaN  2021/12/14 20:31:36+00
# ...                   ...         ...            ...                     ...
# 200915  Shots Fired Calls   20-117367            NaN  2020/05/03 17:36:42+00
# 200916  Shots Fired Calls   21-104299            NaN  2021/05/16 22:39:28+00
# 200922  Shots Fired Calls   21-155393            NaN  2021/07/14 00:40:27+00
# 200926  Shots Fired Calls   21-082066            NaN  2021/04/19 19:37:55+00
# 200929  Shots Fired Calls   22-163279            NaN  2022/07/18 09:54:36+00
#
#                  Occurred_Date NIBRS_Crime_Against     NIBRS_Group  \
# 2       2021/06/01 07:53:55+00      Non NIBRS Data  Non NIBRS Data
# 7       2022/06/02 22:05:12+00      Non NIBRS Data  Non NIBRS Data
# 9       2022/01/16 08:33:11+00      Non NIBRS Data  Non NIBRS Data
# 10      2021/04/14 02:28:39+00      Non NIBRS Data  Non NIBRS Data
# 12      2021/12/14 20:31:36+00      Non NIBRS Data  Non NIBRS Data
# ...                        ...                 ...             ...
# 200915  2020/05/03 17:36:42+00      Non NIBRS Data  Non NIBRS Data
# 200916  2021/05/16 22:39:28+00      Non NIBRS Data  Non NIBRS Data
# 200922  2021/07/14 00:40:27+00      Non NIBRS Data  Non NIBRS Data
# 200926  2021/04/19 19:37:55+00      Non NIBRS Data  Non NIBRS Data
# 200929  2022/07/18 09:54:36+00      Non NIBRS Data  Non NIBRS Data
#
#             NIBRS_Code   Offense_Category                     Offense  ...  \
# 2       Non NIBRS Data  Shots Fired Calls    Sound of Shots Fired (P)  ...
# 7       Non NIBRS Data  Shots Fired Calls    Sound of Shots Fired (P)  ...
# 9       Non NIBRS Data  Shots Fired Calls    Sound of Shots Fired (P)  ...
# 10      Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
# 12      Non NIBRS Data  Shots Fired Calls    Sound of Shots Fired (P)  ...
# ...                ...                ...                         ...  ...
# 200915  Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
# 200916  Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
# 200922  Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
# 200926  Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
# 200929  Non NIBRS Data  Shots Fired Calls  ShotSpotter Activation (P)  ...
#
#         Latitude Longitude      wgsXAnon      wgsYAnon Crime_Count  OBJECTID  \
# 2       44.94921 -93.24995 -1.038054e+07  5.613531e+06           1         3
# 7       45.05098 -93.31065 -1.038729e+07  5.629551e+06           1         8
# 9       44.94836 -93.25059 -1.038061e+07  5.613397e+06           1        10
# 10      45.02847 -93.29062 -1.038507e+07  5.626005e+06           1        11
# 12      44.96717 -93.32183 -1.038854e+07  5.616356e+06           1        13
# ...          ...       ...           ...           ...         ...       ...
# 200915  44.99687 -93.30444 -1.038660e+07  5.621029e+06           1    200916
# 200916  45.00957 -93.29810 -1.038590e+07  5.623029e+06           1    200917
# 200922  45.00684 -93.29304 -1.038533e+07  5.622599e+06           1    200923
# 200926  45.01493 -93.29243 -1.038527e+07  5.623872e+06           1    200927
# 200929  44.99197 -93.29335 -1.038537e+07  5.620259e+06           1    200930
#
#         Date_Occurred  Time_Occurred  Date_Reported  Time_Reported
# 2          2021-06-01       07:53:55     2021-06-01       07:53:55
# 7          2022-06-02       22:05:12     2022-06-02       22:05:12
# 9          2022-01-16       08:33:11     2022-01-16       08:33:11
# 10         2021-04-14       02:28:39     2021-04-14       02:28:39
# 12         2021-12-14       20:31:36     2021-12-14       20:31:36
# ...               ...            ...            ...            ...
# 200915     2020-05-03       17:36:42     2020-05-03       17:36:42
# 200916     2021-05-16       22:39:28     2021-05-16       22:39:28
# 200922     2021-07-14       00:40:27     2021-07-14       00:40:27
# 200926     2021-04-19       19:37:55     2021-04-19       19:37:55
# 200929     2022-07-18       09:54:36     2022-07-18       09:54:36
#
# [39804 rows x 26 columns]

# %%
clean_spotshotter_df = spotshotter_calls_df.drop(["NIBRS_Group", "NIBRS_Crime_Against", "NIBRS_Code", "Case_NumberAlt", "Ward", "wgsXAnon", "wgsYAnon"], axis=1)
clean_spotshotter_df.tail()
# Out:
#                      Type Case_Number           Reported_Date  \
# 200915  Shots Fired Calls   20-117367  2020/05/03 17:36:42+00
# 200916  Shots Fired Calls   21-104299  2021/05/16 22:39:28+00
# 200922  Shots Fired Calls   21-155393  2021/07/14 00:40:27+00
# 200926  Shots Fired Calls   21-082066  2021/04/19 19:37:55+00
# 200929  Shots Fired Calls   22-163279  2022/07/18 09:54:36+00
#
#                  Occurred_Date   Offense_Category                     Offense  \
# 200915  2020/05/03 17:36:42+00  Shots Fired Calls  ShotSpotter Activation (P)
# 200916  2021/05/16 22:39:28+00  Shots Fired Calls  ShotSpotter Activation (P)
# 200922  2021/07/14 00:40:27+00  Shots Fired Calls  ShotSpotter Activation (P)
# 200926  2021/04/19 19:37:55+00  Shots Fired Calls  ShotSpotter Activation (P)
# 200929  2022/07/18 09:54:36+00  Shots Fired Calls  ShotSpotter Activation (P)
#
#                    Problem_Initial               Problem_Final  \
# 200915  ShotSpotter Activation (P)  ShotSpotter Activation (P)
# 200916  ShotSpotter Activation (P)  ShotSpotter Activation (P)
# 200922  ShotSpotter Activation (P)  ShotSpotter Activation (P)
# 200926  ShotSpotter Activation (P)  ShotSpotter Activation (P)
# 200929  ShotSpotter Activation (P)  ShotSpotter Activation (P)
#
#                       Address  Precinct   Neighborhood  Latitude  Longitude  \
# 200915    0017XX MORGAN AVE N       4.0  Willard - Hay  44.99687  -93.30444
# 200916  0029XX HUMBOLDT AVE N       4.0         Jordan  45.00957  -93.29810
# 200922    0026XX DUPONT AVE N       4.0      Hawthorne  45.00684  -93.29304
# 200926      0010XX 33RD AVE N       4.0       McKinley  45.01493  -93.29243
# 200929  0010XX PLYMOUTH AVE N       4.0   Near - North  44.99197  -93.29335
#
#         Crime_Count  OBJECTID Date_Occurred Time_Occurred Date_Reported  \
# 200915            1    200916    2020-05-03      17:36:42    2020-05-03
# 200916            1    200917    2021-05-16      22:39:28    2021-05-16
# 200922            1    200923    2021-07-14      00:40:27    2021-07-14
# 200926            1    200927    2021-04-19      19:37:55    2021-04-19
# 200929            1    200930    2022-07-18      09:54:36    2022-07-18
#
#        Time_Reported
# 200915      17:36:42
# 200916      22:39:28
# 200922      00:40:27
# 200926      19:37:55
# 200929      09:54:36

# %%
#Used this to test for unique values in several columns by changing the column but it's not necessary to run each time
# clean_spotshotter_df.Type.unique()

# %%
#Use the same code to create a df without spotshotter data
mpls_clean_df = mpls_crime_df.loc[mpls_crime_df['NIBRS_Group']== "Group A"]
mpls_clean_df.head()
# Out:
#                      Type Case_Number Case_NumberAlt           Reported_Date  \
# 0  Crime Offenses (NIBRS)   19-244586   MP2019244586  2019/08/15 21:39:00+00
# 1  Crime Offenses (NIBRS)   19-122255   MP2019122255  2019/05/01 13:10:00+00
# 3  Crime Offenses (NIBRS)   20-222716   MP2020222716  2020/08/27 03:26:00+00
# 4  Crime Offenses (NIBRS)   20-703897   MP2020703897  2020/07/12 11:24:00+00
# 5  Crime Offenses (NIBRS)   22-711824   MP2022711824  2022/10/12 08:34:00+00
#
#             Occurred_Date NIBRS_Crime_Against NIBRS_Group NIBRS_Code  \
# 0  2019/08/15 16:00:00+00           Property      Group A        220
# 1  2019/05/01 10:15:00+00           Property      Group A       23F
# 3  2020/08/26 22:54:00+00           Property      Group A        220
# 4  2020/07/12 09:30:00+00           Property      Group A       23H
# 5  2022/10/04 08:00:00+00           Property      Group A       23H
#
#                 Offense_Category                        Offense  ...  \
# 0  Burglary/Breaking & Entering   Burglary/Breaking & Entering   ...
# 1        Larceny/Theft Offenses       Theft From Motor Vehicle   ...
# 3  Burglary/Breaking & Entering   Burglary/Breaking & Entering   ...
# 4        Larceny/Theft Offenses              All Other Larceny   ...
# 5        Larceny/Theft Offenses              All Other Larceny   ...
#
#    Latitude Longitude      wgsXAnon      wgsYAnon Crime_Count  OBJECTID  \
# 0  45.03877 -93.31675 -1.038797e+07  5.627628e+06           1         1
# 1  45.03934 -93.29396 -1.038544e+07  5.627718e+06           1         2
# 3  44.97758 -93.27534 -1.038336e+07  5.617993e+06           1         4
# 4  44.93595 -93.22609 -1.037788e+07  5.611444e+06           1         5
# 5  45.00363 -93.22883 -1.037819e+07  5.622094e+06           1         6
#
#    Date_Occurred  Time_Occurred  Date_Reported  Time_Reported
# 0     2019-08-15       16:00:00     2019-08-15       21:39:00
# 1     2019-05-01       10:15:00     2019-05-01       13:10:00
# 3     2020-08-26       22:54:00     2020-08-27       03:26:00
# 4     2020-07-12       09:30:00     2020-07-12       11:24:00
# 5     2022-10-04       08:00:00     2022-10-12       08:34:00
#
# [5 rows x 26 columns]

# %%
new_mpls_clean_df= mpls_clean_df.drop(["NIBRS_Group", "NIBRS_Code", "Type", "Ward", "wgsXAnon", "wgsYAnon", "Crime_Count", "OBJECTID"], axis=1)
new_mpls_clean_df.head()
# Out:
#   Case_Number Case_NumberAlt           Reported_Date           Occurred_Date  \
# 0   19-244586   MP2019244586  2019/08/15 21:39:00+00  2019/08/15 16:00:00+00
# 1   19-122255   MP2019122255  2019/05/01 13:10:00+00  2019/05/01 10:15:00+00
# 3   20-222716   MP2020222716  2020/08/27 03:26:00+00  2020/08/26 22:54:00+00
# 4   20-703897   MP2020703897  2020/07/12 11:24:00+00  2020/07/12 09:30:00+00
# 5   22-711824   MP2022711824  2022/10/12 08:34:00+00  2022/10/04 08:00:00+00
#
#   NIBRS_Crime_Against               Offense_Category  \
# 0           Property   Burglary/Breaking & Entering
# 1           Property         Larceny/Theft Offenses
# 3           Property   Burglary/Breaking & Entering
# 4           Property         Larceny/Theft Offenses
# 5           Property         Larceny/Theft Offenses
#
#                          Offense                 Problem_Initial  \
# 0  Burglary/Breaking & Entering      Burglary Dwlng - Report (P)
# 1      Theft From Motor Vehicle          Theft - Report Only (P)
# 3  Burglary/Breaking & Entering   Burglary Biz - In Progress (P)
# 4             All Other Larceny                              NaN
# 5             All Other Larceny                              NaN
#
#                     Problem_Final                   Address  Precinct  \
# 0     Burglary Dwlng - Report (P)      0045XX VINCENT AVE N       4.0
# 1         Theft - Report Only (P)       0046XX DUPONT AVE N       4.0
# 3  Burglary Biz - In Progress (P)       0007XX HENNEPIN AVE       1.0
# 4                             NaN          0032XX 37TH ST E       3.0
# 5                             NaN  0014XX NEW BRIGHTON BLVD       2.0
#
#      Neighborhood  Latitude  Longitude Date_Occurred Time_Occurred  \
# 0         Victory  45.03877  -93.31675    2019-08-15      16:00:00
# 1  Lind - Bohanon  45.03934  -93.29396    2019-05-01      10:15:00
# 3   Downtown West  44.97758  -93.27534    2020-08-26      22:54:00
# 4        Standish  44.93595  -93.22609    2020-07-12      09:30:00
# 5  Northeast Park  45.00363  -93.22883    2022-10-04      08:00:00
#
#   Date_Reported Time_Reported
# 0    2019-08-15      21:39:00
# 1    2019-05-01      13:10:00
# 3    2020-08-27      03:26:00
# 4    2020-07-12      11:24:00
# 5    2022-10-12      08:34:00

# %%
# Used to determine column value but not necessary
new_mpls_clean_df.NIBRS_Crime_Against.unique()
# Out:
# array(['Property ', 'Society ', 'Person ', 'Not a Crime '], dtype=object)

# %%
#Attempted to create a dataframe limited for timeline graphic with no success yet
#new_clean_skinny_df = new_mpls_clean_df("Case_Number", "NIBRS_Crime_Against", "Offense", "Latitude", "Longitude", "Date_Occurred", "Time_Occurred")

# %%
#Refactor code from above to create new dfs for crimes against column values
# spotshotter_calls_df = mpls_crime_df.loc[mpls_crime_df['NIBRS_Group']== "Non NIBRS Data"]
# spotshotter_calls_df

property_df = new_mpls_clean_df.loc[new_mpls_clean_df['NIBRS_Crime_Against']== "Property "].drop(["NIBRS_Crime_Against"], axis=1)
property_df
# Out:
#        Case_Number Case_NumberAlt           Reported_Date  \
# 0        19-244586   MP2019244586  2019/08/15 21:39:00+00
# 1        19-122255   MP2019122255  2019/05/01 13:10:00+00
# 3        20-222716   MP2020222716  2020/08/27 03:26:00+00
# 4        20-703897   MP2020703897  2020/07/12 11:24:00+00
# 5        22-711824   MP2022711824  2022/10/12 08:34:00+00
# ...            ...            ...                     ...
# 200923   21-710504   MP2021710504  2021/12/20 15:28:00+00
# 200924   21-285759   MP2021285759  2021/12/14 08:13:00+00
# 200925   22-700897   MP2022700897  2022/01/28 18:35:00+00
# 200927   21-185969   MP2021185969  2021/08/18 02:58:00+00
# 200928   19-268803   MP2019268803  2019/09/05 23:32:00+00
#
#                  Occurred_Date               Offense_Category  \
# 0       2019/08/15 16:00:00+00  Burglary/Breaking & Entering
# 1       2019/05/01 10:15:00+00        Larceny/Theft Offenses
# 3       2020/08/26 22:54:00+00  Burglary/Breaking & Entering
# 4       2020/07/12 09:30:00+00        Larceny/Theft Offenses
# 5       2022/10/04 08:00:00+00        Larceny/Theft Offenses
# ...                        ...                            ...
# 200923  2021/12/06 15:15:00+00        Larceny/Theft Offenses
# 200924  2021/04/25 12:00:00+00        Larceny/Theft Offenses
# 200925  2022/01/22 18:30:00+00        Larceny/Theft Offenses
# 200927  2021/08/18 00:00:00+00                       Robbery
# 200928  2019/08/12 12:30:00+00        Larceny/Theft Offenses
#
#                               Offense                 Problem_Initial  \
# 0       Burglary/Breaking & Entering      Burglary Dwlng - Report (P)
# 1           Theft From Motor Vehicle          Theft - Report Only (P)
# 3       Burglary/Breaking & Entering   Burglary Biz - In Progress (P)
# 4                  All Other Larceny                              NaN
# 5                  All Other Larceny                              NaN
# ...                               ...                             ...
# 200923             All Other Larceny                              NaN
# 200924             All Other Larceny          Theft - Report Only (P)
# 200925      Theft From Motor Vehicle                              NaN
# 200927                       Robbery                   Auto Theft (P)
# 200928             All Other Larceny          Theft - Report Only (P)
#
#                          Problem_Final                   Address  Precinct  \
# 0          Burglary Dwlng - Report (P)      0045XX VINCENT AVE N       4.0
# 1              Theft - Report Only (P)       0046XX DUPONT AVE N       4.0
# 3       Burglary Biz - In Progress (P)       0007XX HENNEPIN AVE       1.0
# 4                                  NaN          0032XX 37TH ST E       3.0
# 5                                  NaN  0014XX NEW BRIGHTON BLVD       2.0
# ...                                ...                       ...       ...
# 200923                             NaN         0015XX LAGOON AVE       5.0
# 200924         Theft - Report Only (P)      0034XX MINNEHAHA AVE       3.0
# 200925                             NaN         0055XX 36TH AVE S       3.0
# 200927    Robbery Dwlng/Person Rpt (P)           0028XX PARK AVE       3.0
# 200928         Theft - Report Only (P)          0033XX 1ST AVE S       5.0
#
#           Neighborhood  Latitude  Longitude Date_Occurred Time_Occurred  \
# 0              Victory  45.03877  -93.31675    2019-08-15      16:00:00
# 1       Lind - Bohanon  45.03934  -93.29396    2019-05-01      10:15:00
# 3        Downtown West  44.97758  -93.27534    2020-08-26      22:54:00
# 4             Standish  44.93595  -93.22609    2020-07-12      09:30:00
# 5       Northeast Park  45.00363  -93.22883    2022-10-04      08:00:00
# ...                ...       ...        ...           ...           ...
# 200923      East Isles  44.94926  -93.30145    2021-12-06      15:15:00
# 200924            Howe  44.94045  -93.22849    2021-04-25      12:00:00
# 200925       Minnehaha  44.90266  -93.22036    2022-01-22      18:30:00
# 200927   Phillips West  44.95014  -93.26520    2021-08-18      00:00:00
# 200928         Lyndale  44.94225  -93.27663    2019-08-12      12:30:00
#
#        Date_Reported Time_Reported
# 0         2019-08-15      21:39:00
# 1         2019-05-01      13:10:00
# 3         2020-08-27      03:26:00
# 4         2020-07-12      11:24:00
# 5         2022-10-12      08:34:00
# ...              ...           ...
# 200923    2021-12-20      15:28:00
# 200924    2021-12-14      08:13:00
# 200925    2022-01-28      18:35:00
# 200927    2021-08-18      02:58:00
# 200928    2019-09-05      23:32:00
#
# [116073 rows x 17 columns]

# %%
#Refactor code from above to create new dfs for crimes against column values

society_df = new_mpls_clean_df.loc[new_mpls_clean_df['NIBRS_Crime_Against']== "Society "].drop(["NIBRS_Crime_Against"], axis=1)
society_df
# Out:
#        Case_Number Case_NumberAlt           Reported_Date  \
# 20       20-092646    MP202092646  2020/04/08 20:43:00+00
# 41       22-234302   MP2022234302  2022/10/02 20:39:00+00
# 64       21-294917   MP2021294917  2021/12/27 01:51:00+00
# 74       22-069459    MP202269459  2022/04/03 15:10:00+00
# 81       19-331787   MP2019331787  2019/11/05 12:49:00+00
# ...            ...            ...                     ...
# 200853   21-116141   MP2021116141  2021/05/30 01:54:00+00
# 200861   20-113308   MP2020113308  2020/04/29 23:01:00+00
# 200862   22-122984   MP2022122984  2022/06/05 16:07:00+00
# 200863   22-149202   MP2022149202  2022/07/03 03:28:00+00
# 200881   19-115089   MP2019115089  2019/04/24 13:46:00+00
#
#                  Occurred_Date         Offense_Category  \
# 20      2020/04/08 20:20:00+00   Weapon Law Violations
# 41      2022/10/02 20:38:00+00   Weapon Law Violations
# 64      2021/12/26 23:33:00+00  Drug/Narcotic Offenses
# 74      2022/04/03 13:45:00+00  Drug/Narcotic Offenses
# 81      2019/11/04 23:00:00+00   Weapon Law Violations
# ...                        ...                      ...
# 200853  2021/05/30 01:21:00+00   Weapon Law Violations
# 200861  2020/04/29 23:01:00+00   Weapon Law Violations
# 200862  2022/06/05 16:07:00+00   Weapon Law Violations
# 200863  2022/07/03 03:27:00+00   Weapon Law Violations
# 200881  2019/04/24 13:46:00+00  Drug/Narcotic Offenses
#
#                            Offense               Problem_Initial  \
# 20          Weapon Law Violations                    On Site (P)
# 41          Weapon Law Violations       Sound of Shots Fired (P)
# 64       Drug/Narcotic Violations                   Domestic (P)
# 74      Drug Equipment Violations           Overdose w/All (PFE)
# 81          Weapon Law Violations   Damage Property-Rpt Only (P)
# ...                            ...                           ...
# 200853      Weapon Law Violations                 Shooting (PFE)
# 200861      Weapon Law Violations    Traffic Law Enforcement (P)
# 200862      Weapon Law Violations     ShotSpotter Activation (P)
# 200863      Weapon Law Violations          Person with a Gun (P)
# 200881   Drug/Narcotic Violations    Traffic Law Enforcement (P)
#
#                        Problem_Final                  Address  Precinct  \
# 20          Sound of Shots Fired (P)      0045XX COLFAX AVE N       4.0
# 41          Sound of Shots Fired (P)        0020XX 10TH AVE S       3.0
# 64               Unwanted Person (P)       0033XX JAMES AVE N       4.0
# 74              Overdose w/All (PFE)         0007XX 16TH ST E       1.0
# 81      Damage Property-Rpt Only (P)        0018XX 26TH AVE N       4.0
# ...                              ...                      ...       ...
# 200853                Shooting (PFE)  0024XX GOLDEN VALLEY RD       4.0
# 200861   Traffic Law Enforcement (P)     0016XX VINCENT AVE N       4.0
# 200862    ShotSpotter Activation (P)      0029XX MORGAN AVE N       4.0
# 200863         Person with a Gun (P)       0015XX LASALLE AVE       1.0
# 200881   Traffic Law Enforcement (P)      0005XX PORTLAND AVE       1.0
#
#            Neighborhood  Latitude  Longitude Date_Occurred Time_Occurred  \
# 20       Lind - Bohanon  45.03757  -93.29267    2020-04-08      20:20:00
# 41      Ventura Village  44.96226  -93.25964    2022-10-02      20:38:00
# 64               Jordan  45.01589  -93.30064    2021-12-26      23:33:00
# 74          Elliot Park  44.96716  -93.26382    2022-04-03      13:45:00
# 81               Jordan  45.00599  -93.30252    2019-11-04      23:00:00
# ...                 ...       ...        ...           ...           ...
# 200853    Willard - Hay  44.99879  -93.31141    2021-05-30      01:21:00
# 200861    Willard - Hay  44.99609  -93.31590    2020-04-29      23:01:00
# 200862           Jordan  45.01051  -93.30443    2022-06-05      16:07:00
# 200863      Loring Park  44.96704  -93.27932    2022-07-03      03:27:00
# 200881      Elliot Park  44.97485  -93.26287    2019-04-24      13:46:00
#
#        Date_Reported Time_Reported
# 20        2020-04-08      20:43:00
# 41        2022-10-02      20:39:00
# 64        2021-12-27      01:51:00
# 74        2022-04-03      15:10:00
# 81        2019-11-05      12:49:00
# ...              ...           ...
# 200853    2021-05-30      01:54:00
# 200861    2020-04-29      23:01:00
# 200862    2022-06-05      16:07:00
# 200863    2022-07-03      03:28:00
# 200881    2019-04-24      13:46:00
#
# [11385 rows x 17 columns]

# %%
#Refactor code from above to create new dfs for crimes against column values
# spotshotter_calls_df = mpls_crime_df.loc[mpls_crime_df['NIBRS_Group']== "Non NIBRS Data"]
# spotshotter_calls_df

person_df = new_mpls_clean_df.loc[new_mpls_clean_df['NIBRS_Crime_Against']== "Person "].drop(["NIBRS_Crime_Against"], axis=1)
person_df
# Out:
#        Case_Number Case_NumberAlt           Reported_Date  \
# 24       19-211206   MP2019211206  2019/07/18 13:02:00+00
# 27       22-191263   MP2022191263  2022/09/12 00:00:00+00
# 37       19-349519   MP2019349519  2019/11/24 01:34:00+00
# 40       20-114365   MP2020114365  2020/04/30 23:39:00+00
# 46       22-256887   MP2022256887  2022/10/28 01:47:00+00
# ...            ...            ...                     ...
# 200892   20-135572   MP2020135572  2020/05/21 08:02:00+00
# 200905   20-201575   MP2020201575  2020/08/03 03:16:00+00
# 200914   22-006276     MP20226276  2022/01/09 22:21:00+00
# 200920   19-145891   MP2019145891  2019/05/23 15:51:00+00
# 200921   21-249214   MP2021249214  2021/10/29 14:14:00+00
#
#                  Occurred_Date   Offense_Category              Offense  \
# 24      2019/07/18 11:56:00+00  Assault Offenses       Simple Assault
# 27      2022/09/12 00:00:00+00  Assault Offenses       Simple Assault
# 37      2019/11/24 01:08:00+00  Assault Offenses       Simple Assault
# 40      2020/04/30 21:17:00+00  Assault Offenses       Simple Assault
# 46      2022/10/28 00:47:00+00  Assault Offenses   Aggravated Assault
# ...                        ...                ...                  ...
# 200892  2020/05/21 07:08:00+00  Assault Offenses       Simple Assault
# 200905  2020/08/03 03:16:00+00  Assault Offenses   Aggravated Assault
# 200914  2022/01/09 21:37:00+00  Assault Offenses         Intimidation
# 200920  2019/05/22 19:00:00+00  Assault Offenses       Simple Assault
# 200921  2021/09/22 00:00:00+00  Assault Offenses         Intimidation
#
#                        Problem_Initial                   Problem_Final  \
# 24            Assist EMS Personnel (P)         Assault in Progress (P)
# 27                   Miscellaneous (P)               Miscellaneous (P)
# 37             Assault in Progress (P)         Assault in Progress (P)
# 40      Domestic Abuse-In Progress (P)  Domestic Abuse-In Progress (P)
# 46                 Unknown Trouble (P)       Domestic with Weapons (P)
# ...                                ...                             ...
# 200892         Assault in Progress (P)         Assault in Progress (P)
# 200905     Traffic Law Enforcement (P)        Shooting Report Only (P)
# 200914                     Threats (P)                     Threats (P)
# 200920         Assault Report Only (P)         Assault Report Only (P)
# 200921           Suspicious Person (P)           Suspicious Person (P)
#
#                           Address  Precinct                     Neighborhood  \
# 24             0027XX ESSEX ST SE       2.0  Prospect Park - East River Road
# 27              0025XX 30TH AVE N       4.0                           Jordan
# 37               0010XX 5TH ST SE       2.0                     Marcy Holmes
# 40               0001XX 33RD ST W       5.0                          Lyndale
# 46      0006XX OLSON MEMORIAL HWY       1.0                       North Loop
# ...                           ...       ...                              ...
# 200892          0053XX 48TH AVE S       3.0                        Minnehaha
# 200905           0010XX 5TH ST SE       2.0                     Marcy Holmes
# 200914            0006XX 7TH ST S       1.0                      Elliot Park
# 200920           0004XX 26TH ST W       5.0                         Whittier
# 200921            0002XX 4TH ST N       1.0                    Downtown West
#
#         Latitude  Longitude Date_Occurred Time_Occurred Date_Reported  \
# 24      44.97027  -93.21940    2019-07-18      11:56:00    2019-07-18
# 27      45.01144  -93.31270    2022-09-12      00:00:00    2022-09-12
# 37      44.98340  -93.23985    2019-11-24      01:08:00    2019-11-24
# 40      44.94293  -93.28051    2020-04-30      21:17:00    2020-04-30
# 46      44.98422  -93.28301    2022-10-28      00:47:00    2022-10-28
# ...          ...        ...           ...           ...           ...
# 200892  44.90630  -93.20503    2020-05-21      07:08:00    2020-05-21
# 200905  44.98340  -93.23985    2020-08-03      03:16:00    2020-08-03
# 200914  44.97313  -93.26339    2022-01-09      21:37:00    2022-01-09
# 200920  44.95553  -93.28486    2019-05-22      19:00:00    2019-05-23
# 200921  44.98083  -93.27195    2021-09-22      00:00:00    2021-10-29
#
#        Time_Reported
# 24          13:02:00
# 27          00:00:00
# 37          01:34:00
# 40          23:39:00
# 46          01:47:00
# ...              ...
# 200892      08:02:00
# 200905      03:16:00
# 200914      22:21:00
# 200920      15:51:00
# 200921      14:14:00
#
# [33667 rows x 17 columns]

# %%
no_crime_df = new_mpls_clean_df.loc[new_mpls_clean_df['NIBRS_Crime_Against']== "Not a Crime "].drop(["NIBRS_Crime_Against"], axis=1)
no_crime_df
# Out:
#       Case_Number Case_NumberAlt           Reported_Date  \
# 16844   22-600269   MP2022600269  2022/02/27 18:30:00+00
#
#                 Occurred_Date    Offense_Category                Offense  \
# 16844  2022/02/27 17:37:00+00  Homicide Offenses   Justifiable Homicide
#
#       Problem_Initial Problem_Final            Address  Precinct Neighborhood  \
# 16844             NaN           NaN  0019XX 30TH AVE N       4.0       Jordan
#
#        Latitude  Longitude Date_Occurred Time_Occurred Date_Reported  \
# 16844  45.01141   -93.3038    2022-02-27      17:37:00    2022-02-27
#
#       Time_Reported
# 16844      18:30:00

# %%
# Used to determine column value but not necessary
new_mpls_clean_df.Offense_Category.unique()
# Out:
# array(['Burglary/Breaking & Entering ', 'Larceny/Theft Offenses ',
#        'Robbery ', 'Motor Vehicle Theft ', 'Weapon Law Violations ',
#        'Destruction/Damage/Vandalism of Property ', 'Assault Offenses ',
#        'Fraud Offenses ', 'Stolen Property Offenses ', 'Sex Offenses ',
#        'Drug/Narcotic Offenses ', 'Counterfeiting/Forgery ',
#        'Embezzlement ', 'Kidnapping/Abduction ', 'Arson ',
#        'Pornography/Obscene Material ', 'Homicide Offenses ',
#        'Animal Cruelty ', 'Extortion/Blackmail ', 'Human Trafficking ',
#        'Gambling Offenses ', 'Prostitution Offenses ', 'Bribery '],
#       dtype=object)

# %%
#wrote this code in the wrong cell: 
#new_mpls_clean_df.groupby('Offense')['Case_Number'].nunique()
person_df.groupby('Offense')['Case_Number'].nunique()
# Out:
# Offense
# Aggravated Assault                            8688
# Human Trafficking, Commercial Sex Acts          39
# Human Trafficking, Involuntary Servitude        26
# Intimidation                                  6129
# Kidnapping/Abduction                           760
# Murder and Nonnegligent Manslaughter           287
# Negligent Manslaughter                          15
# Sex Offenses                                  3003
# Simple Assault                               14697
# Name: Case_Number, dtype: int64

# %%
#finding counts for each df
property_df.groupby('Offense')['Case_Number'].nunique()
# Out:
# Offense
# All Other Larceny                               22669
# Arson                                             410
# Bribery                                             2
# Burglary/Breaking & Entering                    12110
# Counterfeiting/Forgery                           1246
# Credit Card/Automated Teller Machine Fraud       3442
# Destruction/Damage/Vandalism of Property        19607
# Embezzlement                                      227
# Extortion/Blackmail                                90
# False Pretenses/Swindle/Confidence Game          1542
# Hacking/Computer Invasion                          34
# Identity Theft                                   2688
# Impersonation                                      19
# Motor Vehicle Theft                             16301
# Pocket-picking                                     31
# Purse-snatching                                   987
# Robbery                                          6934
# Shoplifting                                      2712
# Stolen Property Offenses                         1774
# Theft From Building                               525
# Theft From Coin-Operated Machine or Device          7
# Theft From Motor Vehicle                        15042
# Theft of Motor Vehicle Parts or Accessories      7473
# Welfare Fraud                                       4
# Wire Fraud                                        197
# Name: Case_Number, dtype: int64

# %%
summary_society_df = society_df.groupby('Offense')['Case_Number'].nunique()
summary_society_df
# Out:
# Offense
# Animal Cruelty                               93
# Assisting or Promoting Prostitution           6
# Betting/Wagering                              3
# Drug Equipment Violations                   943
# Drug/Narcotic Violations                   4827
# Gambling Equipment Violations                 1
# Operating/Promoting/Assisting Gambling        4
# Pornography/Obscene Material                451
# Prostitution                                  8
# Purchasing Prostitution                       3
# Weapon Law Violations                      5046
# Name: Case_Number, dtype: int64

# %%
summary_society_df.plot(x="Case_Number", y="Offense", kind='pie')
plt.show()

# %%
# my attempt to figure out what these columns are by mapping them begins in this cell with code I'm reformatting
#no_crime_df = new_mpls_clean_df.loc[new_mpls_clean_df['NIBRS_Crime_Against']== "Not a Crime "].drop(["NIBRS_Crime_Against"], axis=1)

# x_axis = new_mpls_clean_df['Date_Occurred']
# y_axis = new_mpls_clean_df['wgsYAnon']

# %%
#this had a weird output 
# plt.plot(x_axis, y_axis)

# %%
# Let's try this in a new notebook
# person_df.plot(x="Neighborhood", y="Offense")
#plot.show()

# %%
#Refactor code from above to create new dfs for Neighborhood column values
standish_df = new_mpls_clean_df.loc[new_mpls_clean_df['Neighborhood']== "Standish"]
standish_df.NIBRS_Crime_Against.unique()
# Out:
# array(['Property ', 'Person ', 'Society '], dtype=object)

# %%
#refactoring the code above to create a df for crimes against people for use in the pie chart below
standish_people_df = standish_df.loc[standish_df['NIBRS_Crime_Against']== "Person "]
standish_people_df.head()
# Out:
#      Case_Number Case_NumberAlt           Reported_Date  \
# 350    19-223202   MP2019223202  2019/07/28 20:47:00+00
# 2642   20-268308   MP2020268308  2020/10/19 15:32:00+00
# 2729   19-166504   MP2019166504  2019/06/10 10:47:00+00
# 3265   21-085757    MP202185757  2021/04/25 00:01:00+00
# 3400   19-040327    MP201940327  2019/02/11 10:30:00+00
#
#                Occurred_Date NIBRS_Crime_Against   Offense_Category  \
# 350   2019/07/28 16:47:00+00             Person       Sex Offenses
# 2642  2020/10/16 16:30:00+00             Person   Assault Offenses
# 2729  2019/06/10 09:45:00+00             Person   Assault Offenses
# 3265  2021/04/24 23:10:00+00             Person   Assault Offenses
# 3400  2019/02/07 15:15:00+00             Person   Assault Offenses
#
#                   Offense                 Problem_Initial  \
# 350          Sex Offenses     Crim Sex Conduct/Report (P)
# 2642      Simple Assault                      On Site (P)
# 2729  Aggravated Assault         Stabbing Report Only (P)
# 3265      Simple Assault   Domestic Abuse-In Progress (P)
# 3400      Simple Assault                        Fight (P)
#
#                        Problem_Final             Address  Precinct  \
# 350      Crim Sex Conduct/Report (P)   0037XX 25TH AVE S       3.0
# 2642         Assault Report Only (P)    0032XX 37TH ST E       3.0
# 2729        Stabbing Report Only (P)  0039XX CEDAR AVE S       3.0
# 3265  Domestic Abuse-In Progress (P)    0032XX 37TH ST E       3.0
# 3400                       Fight (P)   0040XX 28TH AVE S       3.0
#
#      Neighborhood  Latitude  Longitude Date_Occurred Time_Occurred  \
# 350      Standish  44.93501  -93.23592    2019-07-28      16:47:00
# 2642     Standish  44.93595  -93.22609    2020-10-16      16:30:00
# 2729     Standish  44.93140  -93.24733    2019-06-10      09:45:00
# 3265     Standish  44.93595  -93.22609    2021-04-24      23:10:00
# 3400     Standish  44.92960  -93.23211    2019-02-07      15:15:00
#
#      Date_Reported Time_Reported
# 350     2019-07-28      20:47:00
# 2642    2020-10-19      15:32:00
# 2729    2019-06-10      10:47:00
# 3265    2021-04-25      00:01:00
# 3400    2019-02-11      10:30:00

# %%
# DOn't know what's up with this
# standish_people_df.Offense.count()

# %%
# # make figure and assign axis objects
# fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(16, 9))
# fig.subplots_adjust(wspace=0)

# # pie chart parameters
# overall_ratios = [.12, .85, .03]
# title="Crime in Standish"
# labels = ['', 'Property', 'Society']
# explode = [0.1, 0, 0]
# # rotate so that first wedge is split by the x-axis
# angle = -180 * overall_ratios[0]
# wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
#                      labels=labels, explode=explode)

# # bar chart parameters
# x_pos = 0
# ratios = [.20, .22, .02, .01, .14, .41]
# age_labels = ['Agg. Assault', 'Intimidation', 'Kiddnapping', 'Murder/Homicide', "Sex Offense", "Simple Assault"]
# bottom = 0
# width = 20

# # Adding from the top matches the legend.
# for j, (height, label) in enumerate(reversed([*zip(ratios, age_labels)])):
#     bottom -= height
#     bc = ax2.bar(0, height, width, bottom=bottom, color='C0', label=label,
#                  alpha=.1 + 0.25 * j)
#     ax2.bar_label(bc, labels=[f"{height:.0%}"], label_type='edge')

# ax2.set_title('Crimes against People')
# ax2.legend()
# ax2.axis('off')
# ax2.set_xlim(- 2.5 * width, 2.5 * width)

# # use ConnectionPatch to draw lines between the two plots
# theta1, theta2 = wedges[0].theta1, wedges[0].theta2
# center, r = wedges[0].center, wedges[0].r
# bar_height = sum(ratios)

# # draw top connecting line
# x = r * np.cos(np.pi / 180 * theta2) + center[0]
# y = r * np.sin(np.pi / 180 * theta2) + center[1]
# con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
#                       xyB=(x, y), coordsB=ax1.transData)
# con.set_color([0, 0, 0])
# con.set_linewidth(1)
# ax2.add_artist(con)

# # draw bottom connecting line
# x = r * np.cos(np.pi / 180 * theta1) + center[0]
# y = r * np.sin(np.pi / 180 * theta1) + center[1]
# con = ConnectionPatch(xyA=(-width / 2, bar_height), coordsA=ax2.transData,
#                       xyB=(x, y), coordsB=ax1.transData)
# con.set_color([0, 0, 0])
# ax2.add_artist(con)
# con.set_linewidth(1)

# plt.savefig("exploding_crime_standish.png")
# plt.show()

# %%
# make figure and assign axis objects
fig = plt.figure(figsize=(16, 9))
ax1 = fig.add_subplot(121)
ax2 = fig.add_subplot(122)
fig.subplots_adjust(wspace=0)
plt.style.use('cyberpunk')
mplcyberpunk.add_glow_effects()
mplcyberpunk.add_gradient_fill()

# pie chart parameters
ratios = [.12, .85, .03]
labels = ['Persons', 'Property', 'Society']
explode = [0.1, 0, 0]
# rotate so that first wedge is split by the x-axis
angle = -180 * ratios[0]
ax1.pie(ratios, autopct='%1.1f%%', startangle=angle,
        labels=labels, explode=explode)

# bar chart parameters
plt.suptitle("Crime in Standish")
xpos = 0
bottom = 0
ratios = [.20, .63, .14, .03]
width = .2
colors = [[.1, .3, .5], [.1, .3, .3], [.1, .3, .7], [.1, .3, .9]]

for j in range(len(ratios)):
    height = ratios[j]
    ax2.bar(xpos, height, width, bottom=bottom, color=colors[j])
    ypos = bottom + ax2.patches[j].get_height() / 2
    bottom += height
    ax2.text(xpos, ypos, "%d%%" % (ax2.patches[j].get_height() * 100),
             ha='center')

ax2.set_title('Crimes against Persons')
ax2.legend(('Kidnapping/Murder/Homicide', 'Sex Crime', 'Simple Assault/Intimidation', 'Agg. Assault'))
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

# use ConnectionPatch to draw lines between the two plots
# get the wedge data
theta1, theta2 = ax1.patches[0].theta1, ax1.patches[0].theta2
center, r = ax1.patches[0].center, ax1.patches[0].r
bar_height = sum([item.get_height() for item in ax2.patches])

# draw top connecting line
x = r * np.cos(np.pi / 180 * theta2) + center[0]
y = np.sin(np.pi / 180 * theta2) + center[1]
con = ConnectionPatch(xyA=(- width / 2, bar_height), xyB=(x, y),
                      coordsA="data", coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
con.set_linewidth(1)
ax2.add_artist(con)

# draw bottom connecting line
x = r * np.cos(np.pi / 180 * theta1) + center[0]
y = np.sin(np.pi / 180 * theta1) + center[1]
con = ConnectionPatch(xyA=(- width / 2, 0), xyB=(x, y), coordsA="data",
                      coordsB="data", axesA=ax2, axesB=ax1)
con.set_color([0, 0, 0])
ax2.add_artist(con)
con.set_linewidth(1)
plt.savefig("standish_crime_cyberpunk.png")
plt.show()

# %%
standish_df.Offense.unique()
# Out:
# array(['All Other Larceny ',
#        'Theft of Motor Vehicle Parts or Accessories ', 'Sex Offenses',
#        'Motor Vehicle Theft ', 'Burglary/Breaking & Entering ',
#        'Robbery ', 'Counterfeiting/Forgery ', 'Theft From Motor Vehicle ',
#        'Drug Equipment Violations ', 'Simple Assault ', 'Embezzlement ',
#        'Aggravated Assault ', 'Drug/Narcotic Violations ',
#        'Identity Theft ', 'Stolen Property Offenses ', 'Intimidation ',
#        'Shoplifting ', 'Destruction/Damage/Vandalism of Property ',
#        'Arson ', 'Credit Card/Automated Teller Machine Fraud ',
#        'Weapon Law Violations ', 'Pornography/Obscene Material ',
#        'False Pretenses/Swindle/Confidence Game ', 'Extortion/Blackmail ',
#        'Wire Fraud ', 'Theft From Building ', 'Kidnapping/Abduction ',
#        'Purse-snatching ', 'Murder and Nonnegligent Manslaughter '],
#       dtype=object)

# %%
standish_types_df = standish_df.NIBRS_Crime_Against.value_counts().to_frame()
standish_types_df.head()
# Out:
#            NIBRS_Crime_Against
# Property                  1323
# Person                     185
# Society                     45

# %%
type_x=standish_types_df.index
type_y=standish_types_df.NIBRS_Crime_Against
print(type_y)
# Out:
# Property     1323
# Person        185
# Society        45
# Name: NIBRS_Crime_Against, dtype: int64

# %%
plt.bar(type_x, type_y, color='green')
plt.xlabel("Category of Crime")
plt.ylabel("Number of Incidents")
plt.title("Crime in Standish by Category")
#plt.legend()
plt.style.use("Solarize_Light2")
plt.savefig('Standish_category_cyberpunk.png')
plt.style.use('cyberpunk')
mplcyberpunk.add_glow_effects()
mplcyberpunk.add_gradient_fill()

# %%
standish_counts_df=standish_df.Offense.value_counts().to_frame()
standish_counts_df
# Out:
#                                               Offense
# Burglary/Breaking & Entering                      239
# Motor Vehicle Theft                               219
# Destruction/Damage/Vandalism of Property          194
# All Other Larceny                                 187
# Theft From Motor Vehicle                          167
# Theft of Motor Vehicle Parts or Accessories       152
# Simple Assault                                     76
# Robbery                                            59
# Intimidation                                       41
# Aggravated Assault                                 37
# Credit Card/Automated Teller Machine Fraud         30
# Identity Theft                                     28
# Sex Offenses                                       26
# Drug/Narcotic Violations                           19
# Weapon Law Violations                              18
# False Pretenses/Swindle/Confidence Game            16
# Stolen Property Offenses                            8
# Counterfeiting/Forgery                              7
# Embezzlement                                        5
# Pornography/Obscene Material                        5
# Drug Equipment Violations                           3
# Wire Fraud                                          3
# Theft From Building                                 3
# Kidnapping/Abduction                                3
# Shoplifting                                         2
# Purse-snatching                                     2
# Murder and Nonnegligent Manslaughter                2
# Arson                                               1
# Extortion/Blackmail                                 1

# %%
# new_df=standish_counts_df.to_frame()
# new_df

# %%
x_axis=standish_counts_df.index
y_axis=standish_counts_df.Offense
y_axis
# Out:
# Burglary/Breaking & Entering                    239
# Motor Vehicle Theft                             219
# Destruction/Damage/Vandalism of Property        194
# All Other Larceny                               187
# Theft From Motor Vehicle                        167
# Theft of Motor Vehicle Parts or Accessories     152
# Simple Assault                                   76
# Robbery                                          59
# Intimidation                                     41
# Aggravated Assault                               37
# Credit Card/Automated Teller Machine Fraud       30
# Identity Theft                                   28
# Sex Offenses                                     26
# Drug/Narcotic Violations                         19
# Weapon Law Violations                            18
# False Pretenses/Swindle/Confidence Game          16
# Stolen Property Offenses                          8
# Counterfeiting/Forgery                            7
# Embezzlement                                      5
# Pornography/Obscene Material                      5
# Drug Equipment Violations                         3
# Wire Fraud                                        3
# Theft From Building                               3
# Kidnapping/Abduction                              3
# Shoplifting                                       2
# Purse-snatching                                   2
# Murder and Nonnegligent Manslaughter              2
# Arson                                             1
# Extortion/Blackmail                               1
# Name: Offense, dtype: int64

# %%
plt.bar(x_axis, y_axis, color="green", label="Types of Crime in Standish", align="center")
plt.xlabel("Type of Crime")
plt.xticks(rotation=30, fontsize=8, ha="right")
plt.ylabel("Instances of Type of Crime")
plt.title("Types of Crime in Standish")
plt.legend()
plt.savefig('most_popular_crimes_cyberpunk.png')
plt.style.use('cyberpunk')
mplcyberpunk.add_gradient_fill()
mplcyberpunk.add_glow_effects()
mplcyberpunk.add_underglow()

# %%
#This works but you need it to keep the rest of the df and just change the dtype of the column
# standish_time_df=standish_df.Occurred_Date.astype('datetime64')
#standish_time_df
